# %%
import pandas as pd
import numpy as np
from geopy import distance

# %%
# location of json file
data = pd.read_json('rqzj-sfat.json')
# Location of union square
union_square_loc = (40.7359, 73.9911)

def get_distance(start, destination):
    return distance.distance(start, destination).miles

# formats points lognitude, latitude to something geopy can understand
data['points'] = (tuple(zip( data['latitude'], data['longitude'])))

# creates new column distance that calculates distance between union square and rows location
data['distance'] = data['points'].apply(lambda row: get_distance(union_square_loc, row))

# prints the 5 smallest distances 
data.nsmallest(n=5, columns=['distance'])
# Out:
#      objectid           applicant facilitytype       cnn  \
# 23    1598474  San Pancho's Tacos        Truck   2801101
# 30    1577173         BH & MT LLC        Truck  10048000
# 39    1337426      Liang Bai Ping        Truck  10215000
# 67    1568951         Senor Sisig        Truck  10456000
# 181   1587522    Chairman SF, LLC        Truck   3528000
#
#                                    locationdescription               address  \
# 23   BAY SHORE BLVD: CORTLAND AVE to WATERLOO ST (4...    491 BAY SHORE BLVD
# 30   OTIS ST: GOUGH ST \ MCCOPPIN ST to 13TH ST \ D...           170 OTIS ST
# 39     PALOU AVE: PALOU AVE to GRIFFITH ST (904 - 999)  Assessors Block /Lot
# 67       PINE ST: SANSOME ST to CENTURY PL (300 - 340)           300 PINE ST
# 181  CALIFORNIA ST: SANSOME ST to LEIDESDORFF ST (4...     400 CALIFORNIA ST
#
#     blocklot block  lot       permit  ...  \
# 23   5598008  5598  008  22MFF-00028  ...
# 30   3513007  3513  007  21MFF-00128  ...
# 39       NaN   NaN  NaN  19MFF-00079  ...
# 67   0260005  0260  005  21MFF-00097  ...
# 181  0238003  0238  003  21MFF-00153  ...
#
#                                               location  \
# 23   {'latitude': '0.0', 'longitude': '0.0', 'human...
# 30   {'latitude': '0.0', 'longitude': '0.0', 'human...
# 39   {'latitude': '0.0', 'longitude': '0.0', 'human...
# 67   {'latitude': '0.0', 'longitude': '0.0', 'human...
# 181  {'latitude': '0.0', 'longitude': '0.0', 'human...
#
#     :@computed_region_yftq_j783  :@computed_region_p5aj_wyqh  \
# 23                          NaN                          NaN
# 30                          NaN                          NaN
# 39                          NaN                          NaN
# 67                          NaN                          NaN
# 181                         NaN                          NaN
#
#      :@computed_region_rxqg_mtj9  :@computed_region_bh8s_q3mv  \
# 23                           NaN                          NaN
# 30                           NaN                          NaN
# 39                           NaN                          NaN
# 67                           NaN                          NaN
# 181                          NaN                          NaN
#
#      :@computed_region_fyvs_ahh9 dayshours noisent      points     distance
# 23                           NaN       NaN     NaN  (0.0, 0.0)  5385.207102
# 30                           NaN       NaN     NaN  (0.0, 0.0)  5385.207102
# 39                           NaN       NaN     NaN  (0.0, 0.0)  5385.207102
# 67                           NaN       NaN     NaN  (0.0, 0.0)  5385.207102
# 181                          NaN       NaN     NaN  (0.0, 0.0)  5385.207102
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Answer
# Alfaro Truck is the closest according to my data analysis

# %%
data.min()
# Out:
# <ipython-input-3-9129c1932162>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.min()
# objectid                                                                  364218
# applicant                                                           Alfaro Truck
# cnn                                                                            0
# address                                                                1 BUSH ST
# permit                                                                12MFF-0083
# status                                                                  APPROVED
# x                                                                    5980806.006
# y                                                                    2086365.377
# latitude                                                                     0.0
# longitude                                                            -122.509596
# schedule                       http://bsm.sfdpw.org/PermitsTracker/reports/re...
# received                                                                20120403
# priorpermit                                                                    0
# :@computed_region_yftq_j783                                                  1.0
# :@computed_region_p5aj_wyqh                                                  1.0
# :@computed_region_rxqg_mtj9                                                  1.0
# :@computed_region_bh8s_q3mv                                                 54.0
# :@computed_region_fyvs_ahh9                                                  1.0
# points                                                                (0.0, 0.0)
# distance                                                             5385.207102
# dtype: object
